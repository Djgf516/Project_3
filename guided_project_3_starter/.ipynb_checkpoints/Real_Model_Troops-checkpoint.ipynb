# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pickle

# %%
# Build our DataFrame
df = pd.read_csv('troop_movements10m.csv')
# Out:
#                    timestamp   unit_id           unit_type  location_x  \
# 0        2023-06-13 17:33:18         1               at-st         2.0
# 1        2023-06-13 17:33:17         2        tie_silencer         4.0
# 2        2023-06-13 17:33:16         3               at-at         0.0
# 3        2023-06-13 17:33:15         4        tie_silencer         6.0
# 4        2023-06-13 17:33:14         5         tie_fighter         0.0
# ...                      ...       ...                 ...         ...
# 9999995  2023-02-18 10:26:20   9999996  resistance_soldier         6.0
# 9999996  2023-02-18 10:26:19   9999997        tie_silencer         8.0
# 9999997  2023-02-18 10:26:18   9999998         tie_fighter         7.0
# 9999998  2023-02-18 10:26:17   9999999         tie_fighter         6.0
# 9999999  2023-02-18 10:26:16  10000000        invalid_unit         NaN
#
#          location_y  destination_x  destination_y    homeworld
# ...

# %%
#Replace invalid_unit with unknown
df.replace('invalid_unit', 'unknown')
# Out:
#                    timestamp   unit_id           unit_type  location_x  \
# 0        2023-06-13 17:33:18         1               at-st         2.0
# 1        2023-06-13 17:33:17         2        tie_silencer         4.0
# 2        2023-06-13 17:33:16         3               at-at         0.0
# 3        2023-06-13 17:33:15         4        tie_silencer         6.0
# 4        2023-06-13 17:33:14         5         tie_fighter         0.0
# ...                      ...       ...                 ...         ...
# 9999995  2023-02-18 10:26:20   9999996  resistance_soldier         6.0
# 9999996  2023-02-18 10:26:19   9999997        tie_silencer         8.0
# 9999997  2023-02-18 10:26:18   9999998         tie_fighter         7.0
# 9999998  2023-02-18 10:26:17   9999999         tie_fighter         6.0
# 9999999  2023-02-18 10:26:16  10000000             unknown         NaN
#
#          location_y  destination_x  destination_y    homeworld
# ...

# %%
#Replace missing with fill
df.ffill(inplace=True)
df
# Out:
#                    timestamp   unit_id           unit_type  location_x  \
# 0        2023-06-13 17:33:18         1               at-st         2.0
# 1        2023-06-13 17:33:17         2        tie_silencer         4.0
# 2        2023-06-13 17:33:16         3               at-at         0.0
# 3        2023-06-13 17:33:15         4        tie_silencer         6.0
# 4        2023-06-13 17:33:14         5         tie_fighter         0.0
# ...                      ...       ...                 ...         ...
# 9999995  2023-02-18 10:26:20   9999996  resistance_soldier         6.0
# 9999996  2023-02-18 10:26:19   9999997        tie_silencer         8.0
# 9999997  2023-02-18 10:26:18   9999998         tie_fighter         7.0
# 9999998  2023-02-18 10:26:17   9999999         tie_fighter         6.0
# 9999999  2023-02-18 10:26:16  10000000        invalid_unit         6.0
#
#          location_y  destination_x  destination_y    homeworld
# ...

# %%
# Convert to Parquet
df.to_parquet('troop_movements10m.parquet')

# %%
#Read parquet file and run model
df2 = pd.read_parquet('troop_movements10m.parquet')
# with open('trained_model.pkl', 'rb') as F:
#     trained_model = pickle.load(F)

trained_model = pickle.load(open('trained_model.pkl', 'rb'))
trained_model.predict(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 7
#       3 # with open('trained_model.pkl', 'rb') as F:
#       4 #     trained_model = pickle.load(F)
#       6 trained_model = pickle.load(open('trained_model.pkl', 'rb'))
# ----> 7 trained_model.predict(df2)
#
# File ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py:426, in BaseDecisionTree.predict(self, X, check_input)
#     403 """Predict class or regression value for X.
#     404
#     405 For a classification model, the predicted class for each sample in X is
#    (...)
#     423     The predicted classes, or the predict values.
#     424 """
#     425 check_is_fitted(self)
# --> 426 X = self._validate_X_predict(X, check_input)
#     427 proba = self.tree_.predict(X)
#     428 n_samples = X.shape[0]
#
# ...
